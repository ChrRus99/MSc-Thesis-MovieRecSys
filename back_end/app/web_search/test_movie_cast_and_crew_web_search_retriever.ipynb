# %% [markdown]
# # Test Movie Web Search Retriever Functions
#
# Tests the `retrieve_movie_plot`, `retrieve_movie_curiosities`, and `retrieve_movie_reviews` functions.

# %%
import os
import sys
import asyncio
import platform
import nest_asyncio
from dotenv import load_dotenv
from pathlib import Path

# Apply nest_asyncio to allow running async functions in Jupyter
nest_asyncio.apply()

# Set event loop policy for Windows if possible
if platform.system() == 'Windows':
    try:
        asyncio.set_event_loop_policy(asyncio.WindowsSelectorEventLoopPolicy())
    except Exception as e:
        print(f"Note: Could not set WindowsSelectorEventLoopPolicy - {e}")

# Dynamically find the project root
project_root_path = Path(os.getcwd()).resolve().parents[2]
dotenv_path = project_root_path / ".env"  # Path to .env

# Load environment variables
load_dotenv(dotenv_path)

# Add the project root to sys.path for module imports
sys.path.append("D:\\Internship\\recsys\\back_end")

# Import the retriever functions
from app.web_search.movie_cast_and_crew_web_search_retriever import (
    retrieve_movie_plot,
    retrieve_movie_curiosities,
    retrieve_movie_reviews
)

# %% [markdown]
# ## Define Test Parameters

# %%
test_movie_title = "The Matrix"
query_curiosities = "Tell me some trivia about The Matrix."
query_reviews = "What did people think of The Matrix?"

# %% [markdown]
# ## Test `retrieve_movie_plot`

# %%
plot_result = await retrieve_movie_plot(test_movie_title)
print(f"Plot for '{test_movie_title}':\n{plot_result[:500]}...")
assert isinstance(plot_result, str)
assert len(plot_result) > 100
# Out:
# Retrieving plot for: The Matrix
# Rate limit detected on attempt 1. Retrying in 5.0 seconds...
# Rate limit detected on attempt 2. Retrying in 10.0 seconds...
# Rate limit detected on attempt 3. Retrying in 20.0 seconds...
# Rate limit hit after 4 attempts. Failing search for query: 'The Matrix site:imdb.com'
# Failed to get IMDb ID for 'The Matrix' after retries: https://html.duckduckgo.com/html 202 Ratelimit
# Could not find IMDb ID for 'The Matrix', falling back to general search.
# Falling back to general web search for plot.
# Rate limit detected on attempt 1. Retrying in 5.0 seconds...
# Rate limit detected on attempt 2. Retrying in 10.0 seconds...
# [INIT].... → Crawl4AI 0.6.1
# [FETCH]... ↓ https://en.wikipedia.org/wiki/The_Matrix                                                             | ✓ | ⏱: 0.35s
# [SCRAPE].. ◆ https://en.wikipedia.org/wiki/The_Matrix                                                             | ✓ | ⏱: 0.93s
# [COMPLETE] ● https://en.wikipedia.org/wiki/The_Matrix                                                             | ✓ | ⏱: 1.29s
# Found main content area using selector: 'main'. Extracting text.
# Plot for The Matrix truncated to 25000 characters.
# Plot for 'The Matrix':
# Toggle the table of contents
# The Matrix
# 85 languages
# Afrikaans
# العربية
# Aragonés
# Asturianu
# Azərbaycanca
# تۆرکجه
# বাংলা
# Беларуская
# Български
# Català
# Чӑвашла
# Cebuano
# Čeština
# Cymraeg
# Dansk
# Deutsch
# Eesti
# Ελληνικά
# Emiliàn e rumagnòl
# Español
# Esperanto
# Euskara
# فارسی
# Français
# Frysk
# Galego
# ГӀалгӀай
# 한국어
# Hawaiʻi
# Հայերեն
# हिन्दी
# Hrvatski
# Ido
# Bahasa Indonesia
# Interlingua
# Íslenska
# Italiano
# עברית
# ಕನ್ನಡ
# ქართული
# Қазақша
# Kiswahili
# Kreyòl ayisyen
# Кыргызча
# Ladino
# Latina
# Latviešu
# Lietuvių
# Limburgs
# Magyar
# Македонски
# മലയാള...

# %% [markdown]
# ## Test `retrieve_movie_curiosities`

# %%
curiosity_chunks = await retrieve_movie_curiosities(test_movie_title, query_curiosities, k=5)
print(f"Retrieved {len(curiosity_chunks)} curiosity chunks for '{test_movie_title}':")
for i, chunk in enumerate(curiosity_chunks):
    print(f"  Chunk {i+1} (Score: {chunk['score']:.4f}, Source: {chunk['source']}): {chunk['text'][:100]}...")
assert isinstance(curiosity_chunks, list)
if curiosity_chunks:
    assert isinstance(curiosity_chunks[0], dict)
    assert 'text' in curiosity_chunks[0]
    assert 'source' in curiosity_chunks[0]
    assert 'score' in curiosity_chunks[0]
# Out:
# Retrieving curiosities for: The Matrix with query: 'Tell me some trivia about The Matrix.'
# Attempting to find trivia on triviaforyou.com with query: "The Matrix" trivia site:triviaforyou.com
# Found potential triviaforyou.com URL: https://triviaforyou.com/matrix-trivia/
# [INIT].... → Crawl4AI 0.6.1
# [FETCH]... ↓ https://triviaforyou.com/matrix-trivia/                                                              | ✓ | ⏱: 0.73s
# [SCRAPE].. ◆ https://triviaforyou.com/matrix-trivia/                                                              | ✓ | ⏱: 0.02s
# [COMPLETE] ● https://triviaforyou.com/matrix-trivia/                                                              | ✓ | ⏱: 0.76s
# Found 'entry-content' div on triviaforyou.com.
# Successfully extracted trivia from triviaforyou.com.
# FAISS index built successfully with 9 vectors.
# Retrieved 5 curiosity chunks for The Matrix.
# Retrieved 5 curiosity chunks for 'The Matrix':
#   Chunk 1 (Score: 0.1828, Source: https://triviaforyou.com/matrix-trivia/): The Matrix is one of the most famous movies of all time. Released in 1999, it changed how people thi...
#   Chunk 2 (Score: 0.2312, Source: https://triviaforyou.com/matrix-trivia/): (Answer: Ongoing technology debates)
# Final Thoughts
# We explored fascinating trivia about The Matrix ...
#   Chunk 3 (Score: 0.2641, Source: https://triviaforyou.com/matrix-trivia/): Matrix Trivia
# The World of The Matrix
# 1. Who is the main protagonist of The Matrix?
# (Answer: Neo)
# 2....
#   Chunk 4 (Score: 0.2799, Source: https://triviaforyou.com/matrix-trivia/): 3. How many times was the original script revised before filming?
# (Answer: Over 10 times)
# 4. What st...
#   Chunk 5 (Score: 0.2801, Source: https://triviaforyou.com/matrix-trivia/): 2. Who says, “Don’t think you are, know you are”?
# (Answer: Morpheus)
# 3. What phrase does the Oracle ...

# %% [markdown]
# ## Test `retrieve_movie_reviews`

# %%
review_chunks = await retrieve_movie_reviews(test_movie_title, query_reviews, initial_k=15)
print(f"Retrieved {len(review_chunks)} review chunks for '{test_movie_title}':")
total_chars = 0
for i, chunk in enumerate(review_chunks):
    print(f"  Chunk {i+1} (Score: {chunk['score']:.4f}, Source: {chunk['source']}): {chunk['text'][:100]}...")
    total_chars += len(chunk.get('text', ''))
print(f"Total characters in retrieved reviews: {total_chars}")
assert isinstance(review_chunks, list)
if review_chunks:
    assert isinstance(review_chunks[0], dict)
    assert 'text' in review_chunks[0]
    assert 'source' in review_chunks[0]
    assert 'score' in review_chunks[0]
assert total_chars <= 25000 # Check character limit
# Out:
# Retrieving reviews for: The Matrix with query: 'What did people think of The Matrix?'
# Attempting to fetch reviews from IMDb: https://www.imdb.com/title/tt0133093/reviews/
# [INIT].... → Crawl4AI 0.6.1
# [FETCH]... ↓ https://www.imdb.com/title/tt0133093/reviews/                                                        | ✓ | ⏱: 0.54s
# [SCRAPE].. ◆ https://www.imdb.com/title/tt0133093/reviews/                                                        | ✓ | ⏱: 0.10s
# [COMPLETE] ● https://www.imdb.com/title/tt0133093/reviews/                                                        | ✓ | ⏱: 0.65s
# Found 94 potential review containers using combined strategies on IMDb page.
# Using fallback text extraction for container: 10
# /
# 10
# Just wow
# When this came out, I was living with a roommate. He went out and saw it, came home...
# Using fallback text extraction for container: When this came out, I was living with a roommate. He went out and saw it, came home and said, "Dude,...
# Using fallback text extraction for container: 10
# /
# 10
# Ah yes. My first existential crisis.
# Spoiler...
# Using fallback text extraction for container: 10
# /
# 10
# Benchmark forever.
# The Matrix - 1999
# This was a real change in filmmaking. Like watching it ...
# Using fallback text extraction for container: The Matrix - 1999
# This was a real change in filmmaking. Like watching it again in 2020, i.e. after 2...
# Using fallback text extraction for container: 10
# /
# 10
# The timeless classic.
# This film doesn't age, it will be contemporary even in 2030 or 2040.
# W...
# Using fallback text extraction for container: This film doesn't age, it will be contemporary even in 2030 or 2040.
# Wachowski's best one, by far....
# Using fallback text extraction for container: 10
# /
# 10
# The benchmark for all sci-fi films to come
# The story of a reluctant Christ-like protagonist ...
# Using fallback text extraction for container: The story of a reluctant Christ-like protagonist set against a baroque, MTV backdrop, The Matrix is ...
# Using fallback text extraction for container: 10
# /
# 10
# A watershed moment in film-making – and what a kick-ass masterpiece
# Spoiler...
# Using fallback text extraction for container: A watershed moment in film-making – and what a kick-ass masterpiece...
# Using fallback text extraction for container: Immensely entertaining, intriguingly philosophical and just about one of the best films ever made!...
# Using fallback text extraction for container: One of the best action sci fi action movies of all time!
# The film is as well crafted as the matrix i...
# Using fallback text extraction for container: One of the best action sci fi action movies of all time!...
# Using fallback text extraction for container: The film is as well crafted as the matrix itself! On another level entirely to any other science fic...
# Using fallback text extraction for container: 10
# /
# 10
# Ever felt like you're living a simulation?
# What if I told you the Matrix is not a Sci-Fi but...
# Using fallback text extraction for container: What if I told you the Matrix is not a Sci-Fi but a Documentary movie?...
# Using fallback text extraction for container: 9
# /
# 10
# One of my favorites
# At first, I wasn't interested in seeing the Matrix. But after hardly hear...
# Using fallback text extraction for container: At first, I wasn't interested in seeing the Matrix. But after hardly hearing any bad reviews for it ...
# Using fallback text extraction for container: 10
# /
# 10
# Welcome to the Real World.
# Without a doubt one of the best and most influential movies of al...
# Using fallback text extraction for container: Without a doubt one of the best and most influential movies of all time, the Matrix is the defining ...
# Using fallback text extraction for container: 5
# /
# 10
# Am I the only one who thinks this movie is overrated? (Major Spoilers)
# Spoiler...
# Using fallback text extraction for container: Am I the only one who thinks this movie is overrated? (Major Spoilers)...
# Using fallback text extraction for container: a masterpiece
# and this is all. because each explanation sounds wrong. sure, the acting,, the plot, t...
# Using fallback text extraction for container: and this is all. because each explanation sounds wrong. sure, the acting,, the plot, the fight/actio...
# Using fallback text extraction for container: 10
# /
# 10
# Almost my favorite movie ever! The metaphors/quotes should be more known!
# Truly a masterpiec...
# Using fallback text extraction for container: Almost my favorite movie ever! The metaphors/quotes should be more known!...
# Using fallback text extraction for container: Truly a masterpiece in every way! If it wasn't for Fight Club this would my favorite; I've been on t...
# Using fallback text extraction for container: 10
# /
# 10
# So well written that makes you questioning the reality. ⭐
# This movie is so well written that...
# Using fallback text extraction for container: So well written that makes you questioning the reality. ⭐...
# Using fallback text extraction for container: This movie is so well written that you can't even prove this movie is wrong about our world. This mo...
# Using fallback text extraction for container: 10
# /
# 10
# The Matrix Is one of the best Classic Sci-Fi Action Film ever
# Spoiler...
# Using fallback text extraction for container: The Matrix Is one of the best Classic Sci-Fi Action Film ever...
# Using fallback text extraction for container: 10
# /
# 10
# Still hip as heck even after 20 years
# You name it. Technology, CGI, flow of the story, the c...
# Using fallback text extraction for container: You name it. Technology, CGI, flow of the story, the concept, action, romance, style, music,... ever...
# Using fallback text extraction for container: 10
# /
# 10
# 20 years on from release, some random thoughts on revisiting The Matrix. Spoiler: It's still...
# Using fallback text extraction for container: 20 years on from release, some random thoughts on revisiting The Matrix. Spoiler: It's still brillia...
# Using fallback text extraction for container: 20 years after its release, and several years since I last saw it, some reflections on the experienc...
# Using fallback text extraction for container: 10
# /
# 10
# The more you watch it, the better it gets
# The Wachowski brothers really did excel themselves...
# Using fallback text extraction for container: The Wachowski brothers really did excel themselves with this movie. It's a brilliant movie on a numb...
# Using fallback text extraction for container: 10
# /
# 10
# Agent Smith: Human beings are a disease, a cancer of this planet. You're a plague and we are...
# Using fallback text extraction for container: Agent Smith: Human beings are a disease, a cancer of this planet. You're a plague and we are the cur...
# Using fallback text extraction for container: 7
# /
# 10
# A good action movie but very overrated
# Spoiler...
# Using fallback text extraction for container: 5
# /
# 10
# A very deep film- if you only watch films at your local multiplex
# I missed this when it was f...
# Using fallback text extraction for container: A very deep film- if you only watch films at your local multiplex...
# Using fallback text extraction for container: I missed this when it was first released. However, at the time I saw clips of the fights scenes and ...
# Using fallback text extraction for container: What is the Matrix?  Well, one of the best films ever, for one thing...
# The Matrix...when I first he...
# Using fallback text extraction for container: What is the Matrix?  Well, one of the best films ever, for one thing......
# Using fallback text extraction for container: The Matrix...when I first heard about it, I expected just another sci-fi action thriller.  Good and ...
# Extracted 49 reviews from IMDb page.
# Successfully extracted reviews from IMDb.
# Extracted 49 individual reviews for indexing.
# FAISS index built successfully with 92 vectors from pre-split docs.
# Retrieved 15 review chunks for The Matrix within character limit.
# Retrieved 15 review chunks for 'The Matrix':
#   Chunk 1 (Score: 0.2380, Source: https://www.imdb.com/title/tt0133093/reviews/): People will say what they want to say about how good The Matrix is but the bottomline is this: final...
#   Chunk 2 (Score: 0.2381, Source: https://www.imdb.com/title/tt0133093/reviews/): People will say what they want to say about how good The Matrix is but the bottomline is this: final...
#   Chunk 3 (Score: 0.2447, Source: https://www.imdb.com/title/tt0133093/reviews/): I missed this when it was first released. However, at the time I saw clips of the fights scenes and ...
#   Chunk 4 (Score: 0.2528, Source: https://www.imdb.com/title/tt0133093/reviews/): In conclusion The Matrix is a masterpiece everyone should see. It is one of the most thought provoki...
#   Chunk 5 (Score: 0.2529, Source: https://www.imdb.com/title/tt0133093/reviews/): In conclusion The Matrix is a masterpiece everyone should see. It is one of the most thought provoki...
#   Chunk 6 (Score: 0.2537, Source: https://www.imdb.com/title/tt0133093/reviews/): The story of a reluctant Christ-like protagonist set against a baroque, MTV backdrop, The Matrix is ...
#   Chunk 7 (Score: 0.2543, Source: https://www.imdb.com/title/tt0133093/reviews/): At first, I wasn't interested in seeing the Matrix. But after hardly hearing any bad reviews for it ...
#   Chunk 8 (Score: 0.2555, Source: https://www.imdb.com/title/tt0133093/reviews/): 9
# /
# 10
# One of my favorites
# At first, I wasn't interested in seeing the Matrix. But after hardly hear...
#   Chunk 9 (Score: 0.2563, Source: https://www.imdb.com/title/tt0133093/reviews/): 10
# /
# 10
# The benchmark for all sci-fi films to come
# The story of a reluctant Christ-like protagonist ...
#   Chunk 10 (Score: 0.2589, Source: https://www.imdb.com/title/tt0133093/reviews/): 5
# /
# 10
# A very deep film- if you only watch films at your local multiplex
# I missed this when it was f...
#   Chunk 11 (Score: 0.2599, Source: https://www.imdb.com/title/tt0133093/reviews/): When this came out, I was living with a roommate. He went out and saw it, came home and said, "Dude,...
#   Chunk 12 (Score: 0.2612, Source: https://www.imdb.com/title/tt0133093/reviews/): 10
# /
# 10
# Just wow
# When this came out, I was living with a roommate. He went out and saw it, came home...
#   Chunk 13 (Score: 0.2664, Source: https://www.imdb.com/title/tt0133093/reviews/): Without a doubt one of the best and most influential movies of all time, the Matrix is the defining ...
#   Chunk 14 (Score: 0.2666, Source: https://www.imdb.com/title/tt0133093/reviews/): 8) All these years later, it turns out The Matrix was somewhat prophetic about the role technology w...
#   Chunk 15 (Score: 0.2666, Source: https://www.imdb.com/title/tt0133093/reviews/): 8) All these years later, it turns out The Matrix was somewhat prophetic about the role technology w...
# Total characters in retrieved reviews: 9946
