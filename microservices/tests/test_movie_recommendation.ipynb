# %% [markdown]
# # Movie Recommendation Service API Tests
#
# This notebook contains tests for the Movie Recommendation Service API endpoints defined in `movie_recommendation/service.py`.

# %%
import sys
import os
import uuid
import requests
import json
import pandas as pd
import time
from IPython.display import display
from dotenv import load_dotenv
from pathlib import Path

# Dynamically find the project root
project_root = Path(os.getcwd()).resolve().parents[1]
dotenv_path = project_root / ".env"  # Path to .env

# Load environment variables from .env file
load_dotenv(dotenv_path)

# Set the base URL for the API
BASE_URL = "http://localhost:" + os.getenv("MOVIE_RECOMMENDATION_MICROSERVICE_PORT")

# %% [markdown]
# ## Test Popularity Ranking Endpoint

# %%
def test_popularity_ranking():
    """Test the popularity ranking endpoint"""
    # Set query parameters
    test_user_id = "bdd62e39-8999-468b-be8a-c36277a93bdc"  
    filtering_params = {
        "genres": ["Action", "Adventure"],
        "year": 1999,
        "top_n": 20
    }

    # Make a GET request to the popularity ranking endpoint with filtering parameters
    response = requests.get(f"{BASE_URL}/users/{test_user_id}/recommendations/popularity_ranking", params=filtering_params)
    print(f'Status Code: {response.status_code}')
    print(f'Response: {response.json()}')
    
    # Parse the response into a pandas DataFrame
    print("Parsed Response:")
    response_data = response.json()
    recommendations_df = pd.DataFrame(response_data)
    display(recommendations_df.head())
    assert response.status_code == 200, 'Failed to fetch popularity ranking recommendations'

# Execute test
test_popularity_ranking()
# Out:
# Status Code: 200
# Response: [{'id': 1893, 'title': 'Star Wars: Episode I - The Phantom Menace', 'year': '1999', 'vote_count': 4526, 'vote_average': 6, 'popularity': 15.649091, 'genres': ['Adventure', 'Action', 'Science Fiction'], 'wr': 5.884709157333329}, {'id': 564, 'title': 'The Mummy', 'year': '1999', 'vote_count': 2796, 'vote_average': 6, 'popularity': 23.984065, 'genres': ['Adventure', 'Action', 'Fantasy'], 'wr': 5.830044238030754}, {'id': 36643, 'title': 'The World Is Not Enough', 'year': '1999', 'vote_count': 878, 'vote_average': 6, 'popularity': 12.130127, 'genres': ['Adventure', 'Action', 'Thriller'], 'wr': 5.641690063901372}, {'id': 8487, 'title': 'Wild Wild West', 'year': '1999', 'vote_count': 1042, 'vote_average': 5, 'popularity': 9.887602, 'genres': ['Action', 'Adventure', 'Comedy', 'Science Fiction', 'Western'], 'wr': 5.1227355496217815}]
# Parsed Response:
#       id                                      title  year  vote_count  \
# 0   1893  Star Wars: Episode I - The Phantom Menace  1999        4526
# 1    564                                  The Mummy  1999        2796
# 2  36643                    The World Is Not Enough  1999         878
# 3   8487                             Wild Wild West  1999        1042
#
#    vote_average  popularity  \
# 0             6   15.649091
# 1             6   23.984065
# 2             6   12.130127
# 3             5    9.887602
#
#                                               genres        wr
# 0               [Adventure, Action, Science Fiction]  5.884709
# 1                       [Adventure, Action, Fantasy]  5.830044
# 2                      [Adventure, Action, Thriller]  5.641690
# 3  [Action, Adventure, Comedy, Science Fiction, W...  5.122736

# %% [markdown]
# ## Test Collaborative Filtering Endpoint

# %%
def test_collaborative_filtering():
    """Test the collaborative filtering endpoint"""
    # Set query parameters
    test_user_id = "bdd62e39-8999-468b-be8a-c36277a93bdc" 
    filtering_params = {
        "genres": ["Comedy"],
        "actors": ["Tom Hanks"],
        "top_n": 20
    }

    # Make a GET request to the collaborative filtering endpoint with filtering parameters
    response = requests.get(f"{BASE_URL}/users/{test_user_id}/recommendations/collaborative_filtering", params=filtering_params)
    print(f'Status Code: {response.status_code}')
    print(f'Response: {response.json()}')
    assert response.status_code == 200, 'Failed to fetch collaborative filtering recommendations'

    # Parse the response into a pandas DataFrame
    print("Parsed Response:")
    response_data = response.json()
    recommendations_df = pd.DataFrame(response_data)
    display(recommendations_df.head())
    assert response.status_code == 200, 'Failed to fetch collaborative filtering recommendations'

# Execute test
test_collaborative_filtering()
# Out:
# Status Code: 200
# Response: [{'userId': 1000, 'movieId': 32694, 'rating': 4.363989353179932, 'adult': False, 'belongs_to_collection': 'The Rutles Collection', 'budget': '0', 'genres': ['Comedy', 'Documentary', 'Foreign'], 'homepage': 'NaN', 'original_language': 'en', 'original_title': "The Rutles 2: Can't Buy Me Lunch", 'overview': "Twenty-three years after the release of the original Beatles mockumentary, 'The Rutles: All You Need Is Cash', famous artists, actors and musicians speak out on how The Rutles influenced them.", 'popularity': 0.321264, 'production_companies': [], 'production_countries': [], 'release_date': '2002-01-01', 'revenue': 0.0, 'runtime': 56.0, 'spoken_languages': ['English'], 'status': 'Released', 'tagline': 'NaN', 'title': "The Rutles 2: Can't Buy Me Lunch", 'vote_average': 7.2, 'vote_count': 3.0, 'year': '2002', 'cast_list': [{'name': 'Eric Idle', 'character': 'Narrator / Dirk McQuickly / Lady Beth Mouse-Peddler'}, {'name': 'Neil Innes', 'character': 'Ron Nasty'}, {'name': 'Ricky Fataar', 'character': "Stig O'Hara"}, {'name': 'John Halsey', 'character': 'Barry Wom'}, {'name': 'David Bowie', 'character': 'Himself - Interviewee'}, {'name': 'Billy Connolly', 'character': 'Interviewee'}, {'name': 'Carrie Fisher', 'character': 'Interviewee'}, {'name': 'Jewel', 'character': 'Interviewee (as Jewel)'}, {'name': 'Mike Nichols', 'character': 'Interviewee'}, {'name': 'Salman Rushdie', 'character': 'Interviewee'}, {'name': 'Garry Shandling', 'character': 'Interviewee'}, {'name': 'April Adams', 'character': 'Groupie Interviewee'}, {'name': 'Clint Black', 'character': 'Interviewee'}, {'name': 'Jimmy Fallon', 'character': 'Reporter'}, {'name': 'Graham Nash', 'character': 'Interviewee'}, {'name': 'Kevin Nealon', 'character': 'Kevin Wongle'}, {'name': "Catherine O'Hara", 'character': 'Astro Glide'}, {'name': 'Bonnie Raitt', 'character': 'Interviewee'}, {'name': 'David A. Stewart', 'character': 'Interviewee'}, {'name': 'James Taylor', 'character': 'Interviewee'}, {'name': 'Jann Wenner', 'character': 'Interviewee'}, {'name': 'Jim Piddock', 'character': 'Troy Nixon'}, {'name': "Conan O'Brien", 'character': 'Interviewee'}, {'name': 'Robin Williams', 'character': ''}, {'name': 'Steve Martin', 'character': ''}, {'name': 'Bill Murray', 'character': ''}, {'name': 'Tom Hanks', 'character': ''}], 'crew_list': [{'job': 'Director', 'name': 'Eric Idle', 'department': 'Directing'}, {'job': 'Writer', 'name': 'Eric Idle', 'department': 'Writing'}]}, {'userId': 1000, 'movieId': 10905, 'rating': 4.184771537780762, 'adult': False, 'belongs_to_collection': None, 'budget': '0', 'genres': ['Action', 'Comedy'], 'homepage': 'NaN', 'original_language': 'en', 'original_title': 'The Man with One Red Shoe', 'overview': 'A man is mistaken as a spy by the CIA when he arrives at the airport with one red shoe.', 'popularity': 4.006022, 'production_companies': ['Twentieth Century Fox Film Corporation'], 'production_countries': ['United States of America'], 'release_date': '1985-07-18', 'revenue': 0.0, 'runtime': 90.0, 'spoken_languages': ['English'], 'status': 'Released', 'tagline': 'Mugged, bugged, chased and seduced. Why is every one after Tom Hanks?', 'title': 'The Man with One Red Shoe', 'vote_average': 5.4, 'vote_count': 74.0, 'year': '1985', 'cast_list': [{'name': 'Tom Hanks', 'character': 'Richard Harlan Drew'}, {'name': 'Dabney Coleman', 'character': 'Cooper'}, {'name': 'Lori Singer', 'character': 'Maddy'}, {'name': 'Charles Durning', 'character': 'Ross'}, {'name': 'Carrie Fisher', 'character': 'Paula'}, {'name': 'Edward Herrmann', 'character': 'Brown'}, {'name': 'Jim Belushi', 'character': 'Morris'}, {'name': 'Irving Metzman', 'character': 'Virdon'}, {'name': 'Tom Noonan', 'character': 'Reese'}, {'name': 'Gerrit Graham', 'character': 'Carson'}, {'name': 'David L. Lander', 'character': 'Stemple'}, {'name': 'Ritch Brinkley', 'character': 'Hulse'}, {'name': 'Frank Hamilton', 'character': 'Edgar'}, {'name': 'Dortha Duckworth', 'character': 'Natalie'}, {'name': 'Davi ...
# Parsed Response:
#    userId  movieId    rating  adult  belongs_to_collection    budget  \
# 0    1000    32694  4.363989  False  The Rutles Collection         0
# 1    1000    10905  4.184772  False                   None         0
# 2    1000      858  3.943289  False                   None  21000000
# 3    1000     6538  3.844946  False                   None  75000000
# 4    1000     2280  3.745017  False                   None  18000000
#
#                                       genres  \
# 0             [Comedy, Documentary, Foreign]
# 1                           [Action, Comedy]
# 2                   [Comedy, Drama, Romance]
# 3                   [Comedy, Drama, History]
# 4  [Fantasy, Drama, Comedy, Romance, Family]
#
#                             homepage original_language  \
# 0                                NaN                en
# 1                                NaN                en
# 2                                NaN                en
# 3  http://www.charliewilsonswar.net/                en
# 4                                NaN                en
#
#                      original_title  ... runtime  \
# 0  The Rutles 2: Can't Buy Me Lunch  ...    56.0
# 1         The Man with One Red Shoe  ...    90.0
# 2              Sleepless in Seattle  ...   105.0
# 3              Charlie Wilson's War  ...   102.0
# 4                               Big  ...   104.0
#
#                               spoken_languages    status  \
# 0                                    [English]  Released
# 1                                    [English]  Released
# 2                                    [English]  Released
# 3  [العربية, English, Pусский, اردو, עִבְרִית]  Released
# 4                                    [English]  Released
#
#                                              tagline  \
# 0                                                NaN
# 1  Mugged, bugged, chased and seduced. Why is eve...
# 2  What if someone you never met, someone you nev...
# 3  Based on a true story. You think we could make...
# 4  You're Only Young Once But For Josh It Might J...
#
#                               title  vote_average  vote_count  year  \
# 0  The Rutles 2: Can't Buy Me Lunch           7.2         3.0  2002
# 1         The Man with One Red Shoe           5.4        74.0  1985
# 2              Sleepless in Seattle           6.5       630.0  1993
# 3              Charlie Wilson's War           6.5       342.0  2007
# 4                               Big           6.9      1022.0  1988
#
#                                            cast_list  \
# 0  [{'name': 'Eric Idle', 'character': 'Narrator ...
# 1  [{'name': 'Tom Hanks', 'character': 'Richard H...
# 2  [{'name': 'Tom Hanks', 'character': 'Sam Baldw...
# 3  [{'name': 'Tom Hanks', 'character': 'Charlie W...
# 4  [{'name': 'Tom Hanks', 'character': 'Joshua "J...
#
#                                            crew_list
# 0  [{'job': 'Director', 'name': 'Eric Idle', 'dep...
# 1  [{'job': 'Original Music Composer', 'name': 'T...
# 2  [{'job': 'Director', 'name': 'Nora Ephron', 'd...
# 3  [{'job': 'Producer', 'name': 'Tom Hanks', 'dep...
# 4  [{'job': 'Director', 'name': 'Penny Marshall',...
#
# [5 rows x 26 columns]

# %% [markdown]
# ## Test Hybrid Filtering Endpoint

# %%
def test_hybrid_filtering():
    """Test the hybrid filtering endpoint"""
    # Set query parameters
    test_user_id = "bdd62e39-8999-468b-be8a-c36277a93bdc" 
    filtering_params = {
        'movie_title': 'Inception',
        'top_n': 20,
    }

    # Make a GET request to the hybrid filtering endpoint with filtering parameters
    response = requests.get(f"{BASE_URL}/users/{test_user_id}/recommendations/hybrid_filtering", params=filtering_params)
    print(f'Status Code: {response.status_code}')
    print(f'Response: {response.json()}')
    assert response.status_code == 200, 'Failed to fetch hybrid filtering recommendations'

    # Parse the response into a pandas DataFrame
    print("Parsed Response:")
    response_data = response.json()
    recommendations_df = pd.DataFrame(response_data)
    display(recommendations_df.head())
    assert response.status_code == 200, 'Failed to fetch hybrid filtering recommendations'

# Execute test
test_hybrid_filtering()
# Out:
# Status Code: 200
# Response: [{'id': 272, 'title': 'Batman Begins', 'year': '2005', 'soup': 'christianbale michaelcaine liamneeson christophernolan christophernolan christophernolan Action Crime Drama', 'est_rating': 3.778707265853882, 'gt_rating': None}, {'id': 9623, 'title': 'The Juror', 'year': '1996', 'soup': 'demimoore alecbaldwin josephgordon-levitt briangibson briangibson briangibson Drama Thriller', 'est_rating': 3.509732961654663, 'gt_rating': None}, {'id': 2348, 'title': 'Holy Matrimony', 'year': '1994', 'soup': 'patriciaarquette josephgordon-levitt arminmueller-stahl leonardnimoy leonardnimoy leonardnimoy Comedy', 'est_rating': 3.4370415210723877, 'gt_rating': None}, {'id': 49026, 'title': 'The Dark Knight Rises', 'year': '2012', 'soup': 'christianbale michaelcaine garyoldman christophernolan christophernolan christophernolan Action Crime Drama Thriller', 'est_rating': 3.351440191268921, 'gt_rating': None}, {'id': 43629, 'title': 'Doodlebug', 'year': '1997', 'soup': 'jeremytheobald christophernolan christophernolan christophernolan Fantasy Mystery', 'est_rating': 3.2798149585723877, 'gt_rating': None}, {'id': 43629, 'title': 'Doodlebug', 'year': '1997', 'soup': 'jeremytheobald christophernolan christophernolan christophernolan Fantasy Mystery', 'est_rating': 3.2798149585723877, 'gt_rating': None}, {'id': 1124, 'title': 'The Prestige', 'year': '2006', 'soup': 'hughjackman christianbale michaelcaine christophernolan christophernolan christophernolan Drama Mystery Thriller', 'est_rating': 3.2532460689544678, 'gt_rating': None}, {'id': 157336, 'title': 'Interstellar', 'year': '2014', 'soup': 'matthewmcconaughey jessicachastain annehathaway christophernolan christophernolan christophernolan Adventure Drama Science Fiction', 'est_rating': 3.14284086227417, 'gt_rating': None}, {'id': 155, 'title': 'The Dark Knight', 'year': '2008', 'soup': 'christianbale michaelcaine heathledger christophernolan christophernolan christophernolan Drama Action Crime Thriller', 'est_rating': 3.0610830783843994, 'gt_rating': None}, {'id': 9016, 'title': 'Treasure Planet', 'year': '2002', 'soup': 'josephgordon-levitt brianmurray davidhydepierce ronclements ronclements ronclements Adventure Animation Family Fantasy Science Fiction', 'est_rating': 3.043926954269409, 'gt_rating': None}, {'id': 49526, 'title': 'Premium Rush', 'year': '2012', 'soup': 'josephgordon-levitt michaelshannon daniaramirez davidkoepp davidkoepp davidkoepp Crime Action Thriller', 'est_rating': 3.0228452682495117, 'gt_rating': None}, {'id': 374720, 'title': 'Dunkirk', 'year': '2017', 'soup': 'fionnwhitehead tomglynn-carney jacklowden christophernolan christophernolan christophernolan Action Drama History Thriller War', 'est_rating': 2.9645676612854004, 'gt_rating': None}, {'id': 320, 'title': 'Insomnia', 'year': '2002', 'soup': 'alpacino robinwilliams hilaryswank christophernolan christophernolan christophernolan Crime Mystery Thriller', 'est_rating': 2.9576876163482666, 'gt_rating': None}, {'id': 302401, 'title': 'Snowden', 'year': '2016', 'soup': 'josephgordon-levitt shailenewoodley melissaleo oliverstone oliverstone oliverstone Drama Thriller', 'est_rating': 2.9364917278289795, 'gt_rating': None}, {'id': 285783, 'title': 'The Walk', 'year': '2015', 'soup': 'josephgordon-levitt benkingsley charlottelebon robertzemeckis robertzemeckis robertzemeckis Adventure Drama Thriller', 'est_rating': 2.934643507003784, 'gt_rating': None}, {'id': 59967, 'title': 'Looper', 'year': '2012', 'soup': 'josephgordon-levitt brucewillis emilyblunt rianjohnson rianjohnson rianjohnson Action Thriller Science Fiction', 'est_rating': 2.925217866897583, 'gt_rating': None}, {'id': 138697, 'title': 'Don Jon', 'year': '2013', 'soup': 'josephgordon-levitt scarlettjohansson juliannemoore josephgordon-levitt josephgordon-levitt josephgordon-levitt Romance Comedy Drama', 'est_rating': 2.811095952987671, 'gt_rating': None}, {'id': 56272, 'title': 'Elektra Luxx', 'year': '2010', 'soup': 'carlagugino josephgordon-levitt timothyo ...
# Parsed Response:
#       id                  title  year  \
# 0    272          Batman Begins  2005
# 1   9623              The Juror  1996
# 2   2348         Holy Matrimony  1994
# 3  49026  The Dark Knight Rises  2012
# 4  43629              Doodlebug  1997
#
#                                                 soup  est_rating gt_rating
# 0  christianbale michaelcaine liamneeson christop...    3.778707      None
# 1  demimoore alecbaldwin josephgordon-levitt bria...    3.509733      None
# 2  patriciaarquette josephgordon-levitt arminmuel...    3.437042      None
# 3  christianbale michaelcaine garyoldman christop...    3.351440      None
# 4  jeremytheobald christophernolan christophernol...    3.279815      None
